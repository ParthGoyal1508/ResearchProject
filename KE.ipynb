# %%
import pandas as pd 
from sklearn.utils import shuffle
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.decomposition import PCA

# %%
df = pd.read_csv('data_k_combined.csv')
df = shuffle(df)

# %%
x = df.drop(['0'], axis=1)
y = df['0']
print(x.shape)
print(y.shape)
# Out:
# (1568, 301)
# (1568,)

# %%
def calculate_accuracy(y_predict_model, y): 
  for i in range (len(y_predict_model)): 
    if y_predict_model[i] < 0.5: 
      y_predict_model[i] = 0
    else: 
      y_predict_model[i] = 1

  accurate = 0 
  total = len(y_predict_model) 
  for i in range(len(y_predict_model)): 
    if y_predict_model[i] == y[i]: 
      accurate += 1 
  return (accurate/total)

# %%
model = Sequential([
  Dense(330, activation='tanh', input_shape=(301,)),
  Dense(1, activation='sigmoid'),
])

# Compile the model.
model.compile(
  optimizer='adam',
  loss='binary_crossentropy',
  metrics=['accuracy'],
)

model.fit(
  x, # training data
  y, # training targets
  epochs=2,
  batch_size=56,
)

y_predict_model = model.predict(x)
accuracy_model1 = calculate_accuracy(y_predict_model, y)
print(accuracy_model1)
# Out:
# Epoch 1/2
# 28/28 [==============================] - 0s 2ms/step - loss: 0.7021 - accuracy: 0.6747
# Epoch 2/2
# 28/28 [==============================] - 0s 3ms/step - loss: 0.4231 - accuracy: 0.8510
# 0.4968112244897959

# %%
model2 = Sequential([
  Dense(330, activation='tanh', input_shape=(301,)),
  Dense(340, activation='tanh'),
  Dense(1, activation='sigmoid'),
])

# Compile the model.
model2.compile(
  optimizer='adam',
  loss='binary_crossentropy',
  metrics=['accuracy'],
)

model2.fit(
  x, # training data
  y, # training targets
  epochs=2,
  batch_size=56,
)

y_predict_model2 = model2.predict(x)
accuracy_model2 = calculate_accuracy(y_predict_model2, y)
print(accuracy_model2)
# Out:
# Epoch 1/2
# 28/28 [==============================] - 0s 4ms/step - loss: 0.7762 - accuracy: 0.6363
# Epoch 2/2
# 28/28 [==============================] - 0s 5ms/step - loss: 0.4485 - accuracy: 0.8104
# 0.4897959183673469

# %%
model3 = Sequential([
  Dense(330, activation='tanh', input_shape=(301,)),
  Dense(340, activation='tanh'),
  Dense(350, activation='tanh'),
  Dense(1, activation='sigmoid'),
])

# Compile the model.
model3.compile(
  optimizer='adam',
  loss='binary_crossentropy',
  metrics=['accuracy'],
)

model3.fit(
  x, # training data
  y, # training targets
  epochs=2,
  batch_size=56,
)

y_predict_model3 = model3.predict(x)
accuracy_model3 = calculate_accuracy(y_predict_model3, y)
print(accuracy_model3)
# Out:
# Epoch 1/2
# 28/28 [==============================] - 1s 5ms/step - loss: 0.8741 - accuracy: 0.6006
# Epoch 2/2
# 28/28 [==============================] - 0s 6ms/step - loss: 0.4230 - accuracy: 0.8247
# 0.4955357142857143

# %%
model4 = Sequential([
  Dense(330, activation='tanh', input_shape=(301,)),
  Dense(340, activation='tanh'),
  Dense(350, activation='tanh'),
  Dense(1, activation='sigmoid'),
])

# Compile the model.
model4.compile(
  optimizer='adam',
  loss='binary_crossentropy',
  metrics=['accuracy'],
)

model4.fit(
  x, # training data
  y, # training targets
  epochs=10,
  batch_size=56,
)

y_predict_model4 = model4.predict(x)
accuracy_model4 = calculate_accuracy(y_predict_model4, y)
print(accuracy_model4)
# Out:
# Epoch 1/10
# 28/28 [==============================] - 1s 7ms/step - loss: 0.7415 - accuracy: 0.6372
# Epoch 2/10
# 28/28 [==============================] - 0s 6ms/step - loss: 0.4722 - accuracy: 0.7895
# Epoch 3/10
# 28/28 [==============================] - 0s 6ms/step - loss: 0.4201 - accuracy: 0.8205
# Epoch 4/10
# 28/28 [==============================] - 0s 6ms/step - loss: 0.4198 - accuracy: 0.8148
# Epoch 5/10
# 28/28 [==============================] - 0s 5ms/step - loss: 0.3618 - accuracy: 0.8520
# Epoch 6/10
# 28/28 [==============================] - 0s 5ms/step - loss: 0.3791 - accuracy: 0.8419
# Epoch 7/10
# 28/28 [==============================] - 0s 5ms/step - loss: 0.3388 - accuracy: 0.8630
# Epoch 8/10
# 28/28 [==============================] - 0s 5ms/step - loss: 0.3758 - accuracy: 0.8312
# Epoch 9/10
# 28/28 [==============================] - 0s 5ms/step - loss: 0.3939 - accuracy: 0.8294
# Epoch 10/10
# 28/28 [==============================] - 0s 5ms/step - loss: 0.3499 - accuracy: 0.8492
# 0.48915816326530615

# %%
model5 = Sequential([
  Dense(330, activation='tanh', input_shape=(301,)),
  Dense(340, activation='tanh'),
  Dense(350, activation='tanh'),
  Dense(1, activation='sigmoid'),
])

# Compile the model.
model5.compile(
  optimizer='adam',
  loss='binary_crossentropy',
  metrics=['accuracy'],
)

model5.fit(
  x, # training data
  y, # training targets
  epochs=20,
  batch_size=56,
)

y_predict_model5 = model5.predict(x)
print(calculate_accuracy(y_predict_model5, y))
# Out:
# Epoch 1/20
# 28/28 [==============================] - 1s 5ms/step - loss: 0.9108 - accuracy: 0.6006
# Epoch 2/20
# 28/28 [==============================] - 0s 5ms/step - loss: 0.5243 - accuracy: 0.7351
# Epoch 3/20
# 28/28 [==============================] - 0s 5ms/step - loss: 0.4039 - accuracy: 0.8283
# Epoch 4/20
# 28/28 [==============================] - 0s 6ms/step - loss: 0.4043 - accuracy: 0.8235
# Epoch 5/20
# 28/28 [==============================] - 0s 6ms/step - loss: 0.4486 - accuracy: 0.8019
# Epoch 6/20
# 28/28 [==============================] - 0s 6ms/step - loss: 0.3866 - accuracy: 0.8360
# Epoch 7/20
# 28/28 [==============================] - 0s 5ms/step - loss: 0.3579 - accuracy: 0.8501
# Epoch 8/20
# 28/28 [==============================] - 0s 5ms/step - loss: 0.3765 - accuracy: 0.8292
# Epoch 9/20
# 28/28 [==============================] - 0s 5ms/step - loss: 0.3654 - accuracy: 0.8587
# Epoch 10/20
# 28/28 [==============================] - 0s 6ms/step - loss: 0.3609 - accuracy: 0.8474
# Epoch 11/20
# 28/28 [==============================] - 0s 6ms/step - loss: 0.3335 - accuracy: 0.8663
# Epoch 12/20
# 28/28 [==============================] - 0s 6ms/step - loss: 0.3854 - accuracy: 0.8323
# Epoch 13/20
# 28/28 [==============================] - 0s 6ms/step - loss: 0.3645 - accuracy: 0.8588
# Epoch 14/20
# 28/28 [==============================] - 0s 6ms/step - loss: 0.3623 - accuracy: 0.8425
# Epoch 15/20
# 28/28 [==============================] - 0s 5ms/step - loss: 0.3636 - accuracy: 0.8573
# Epoch 16/20
# 28/28 [==============================] - 0s 6ms/step - loss: 0.3515 - accuracy: 0.8492
# Epoch 17/20
# 28/28 [==============================] - 0s 6ms/step - loss: 0.3200 - accuracy: 0.8657
# Epoch 18/20
# 28/28 [==============================] - 0s 5ms/step - loss: 0.3936 - accuracy: 0.8177
# Epoch 19/20
# 28/28 [==============================] - 0s 6ms/step - loss: 0.2966 - accuracy: 0.8806
# Epoch 20/20
# 28/28 [==============================] - 0s 5ms/step - loss: 0.3272 - accuracy: 0.8737
# 0.48533163265306123

# %%
#@title Default title text
pca = PCA(n_components=3)
x_pca = pca.fit_transform(x)
y_pca = y

# %%
from mpl_toolkits import mplot3d
import matplotlib.pyplot as plt
import numpy as np 
 
# Creating dataset
x_axis = x_pca[:,0]
y_axis = x_pca[:,1]
z_axis = x_pca[:,2]
 
y_pca_zero = np.where(y_pca == 0)[0]
y_pca_one = np.where(y_pca == 1)[0]


# Creating figure
fig = plt.figure(figsize = (10, 7))
ax = plt.axes(projection ="3d")
 
# Creating plot
ax.scatter3D(x_axis[y_pca_zero], y_axis[y_pca_zero], z_axis[y_pca_zero], color = "red")
ax.scatter3D(x_axis[y_pca_one], y_axis[y_pca_one], z_axis[y_pca_one], color = "blue")
plt.title("3D scatter plot using original labels")
 
# show plot
plt.show()

# Creating figure
fig2 = plt.figure(figsize = (10, 7))
ax2 = plt.axes(projection ="3d")

y_predict_zero = np.where(y_predict_model5 == 0)[0]
y_predict_one = np.where(y_predict_model5 == 1)[0]
# Creating plot
ax2.scatter3D(x_axis[y_predict_zero], y_axis[y_predict_zero], z_axis[y_predict_zero], color = "red")
ax2.scatter3D(x_axis[y_predict_one], y_axis[y_predict_one], z_axis[y_predict_one], color = "blue")
plt.title("3D scatter plot using predicted labels")
 
# show plot
plt.show()
